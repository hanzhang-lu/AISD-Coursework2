# %% [markdown]
# # Load Packages

# %%
import subprocess
import os

result = subprocess.run('bash -c "source /etc/network_turbo && env | grep proxy"', shell=True, capture_output=True, text=True)
output = result.stdout
for line in output.splitlines():
    if '=' in line:
        var, value = line.split('=', 1)
        os.environ[var] = value

# %%
# Import packages
import tensorflow as tf
import keras
import numpy as np
import pandas as pd
import PIL
import pathlib
import os
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.losses import *
import requests
import pyunpack
import matplotlib.pyplot as plt
from keras import backend as K
from keras.callbacks import ModelCheckpoint
import sys

from rarfile import RarFile
import segmentation_models as sm
from keras_segmentation.models import segnet
from keras.applications import vgg16
from sklearn.metrics import *
import rioxarray as rxr
from tensorflow.keras.preprocessing.image import ImageDataGenerator

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# 2025-12-09 17:24:42.497616: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Segmentation Models: using `keras` framework.

# %% [markdown]
# # Functions

# %%
'''
  Metric functions for evaluation - OPTIMIZED: Single forward pass for all metrics
'''

def evaluate_all_metrics(model, images, masks, num_classes=5):
    """
    Compute all metrics with a single forward pass through the model.
    FIXED: Handles Deep Supervision (Multiple Outputs)
    """
    print(f"  Processing {len(images)} images...")
    
    all_predictions = []
    all_masks = []
    
    # Single forward pass for all images
    for i in range(len(images)):
        if i % 100 == 0:
            print(f"    {i}/{len(images)}")
        
        img = images[i].reshape(1, 512, 512, 3)
        
        
        raw_output = model.predict(img, verbose=0)
        
      
        if isinstance(raw_output, list):
            
            reconstruction = raw_output[0] 
        else:
           
            reconstruction = raw_output
    
            
        reconstruction = np.argmax(reconstruction, axis=-1).flatten()  # Convert to class indices
        
        all_predictions.append(reconstruction)
        all_masks.append(masks[i].flatten())
    
    print(f"    {len(images)}/{len(images)} - Done!")
    
    # Now compute all metrics from the predictions
    print("  Computing metrics from predictions...")
    
    metrics = {
        'accuracy': [],
        'precision': [],
        'recall': [],
        'iou': [],
        'miou': []
    }
    
    for pred, mask in zip(all_predictions, all_masks):
        # Accuracy
        metrics['accuracy'].append(accuracy_score(mask, pred))
        
        # Precision
        metrics['precision'].append(precision_score(mask, pred, average='weighted', zero_division=0))
        
        # Recall
        metrics['recall'].append(recall_score(mask, pred, average='weighted', zero_division=0))
        
        # IoU (Jaccard)
        metrics['iou'].append(jaccard_score(mask, pred, average='weighted', zero_division=0))
        
        # Mean IoU (per-class IoU)
        iou_per_class = []
        for cls in range(num_classes):
            intersection = np.sum((mask == cls) & (pred == cls))
            union = np.sum((mask == cls) | (pred == cls))
            if union > 0:
                iou_per_class.append(intersection / union)
            else:
                iou_per_class.append(0) # Or nan, depending on preference
        metrics['miou'].append(np.mean(iou_per_class))
    
    return metrics
def f1_score_from_metrics(precision, recall):
    """Compute F1 score from precision and recall"""
    prec = np.mean(precision)
    rec = np.mean(recall)
    
    if prec + rec == 0:
        return 0
    
    return 2 * (prec * rec) / (prec + rec)


# Keep old functions for backward compatibility (not used in new evaluation)
def score_eval(model, image, mask):
    if type(image) != list:   
        reconstruction = model.predict(image, verbose=0, batch_size=32)
        reconstruction = np.argmax(reconstruction, axis=-1).flatten()
        mask_flat = mask.flatten()
        return accuracy_score(mask_flat, reconstruction)
    else:
        scores = []
        for i in range(len(image)):
            img = image[i].reshape(1, 512, 512, 3)
            reconstruction = model.predict(img, verbose=0)
            reconstruction = np.argmax(reconstruction, axis=-1).flatten()
            scores.append(accuracy_score(mask[i].flatten(), reconstruction))
        return scores

def produce_mask(image):
    return np.argmax(image, axis=-1)

# %% [markdown]
# # Models

# %% [markdown]
# ## Attention U-Net (5 Classes)

# %%
def convBlock(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
  else:
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)

  conv = Activation(act)(conv)
  return conv
  
def convBlock2(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)
  else:
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)

  return conv


def convBlock2_improved(input, filters, kernel, kernel_init='he_normal', act='relu'):
  # First conv + BN + activation
  conv = Conv2D(filters, kernel, padding='same', kernel_initializer=kernel_init)(input)
  conv = BatchNormalization()(conv)
  conv = Activation(act)(conv)
  
  # Second conv + BN + activation
  conv = Conv2D(filters, kernel, padding='same', kernel_initializer=kernel_init)(conv)
  conv = BatchNormalization()(conv)
  conv = Activation(act)(conv)

  return conv

'''
  Deeper bottleneck block 
'''
def bottleneck_block(input, filters, kernel_init='he_normal'):
 
  conv = Conv2D(filters, 3, padding='same', kernel_initializer=kernel_init)(input)
  conv = BatchNormalization()(conv)
  conv = Activation('relu')(conv)
  
  conv = Conv2D(filters, 3, padding='same', kernel_initializer=kernel_init)(conv)
  conv = BatchNormalization()(conv)
  conv = Activation('relu')(conv)
  
  conv = Conv2D(filters, 3, padding='same', kernel_initializer=kernel_init)(conv)
  conv = BatchNormalization()(conv)
  conv = Activation('relu')(conv)
  
  return conv
  
'''
  Attention block/mechanism with BatchNorm
'''
def attention_block(x, gating, inter_shape, drop_rate=0.25):
   
    # Find shape of inputs
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    ## Process x vector and gating signal
    theta_x = Conv2D(inter_shape, kernel_size=1, strides=1, padding='same', 
                     kernel_initializer='he_normal', activation=None)(x)
    theta_x = BatchNormalization()(theta_x)
    theta_x = MaxPooling2D((2,2))(theta_x)

    # gating signal
    phi_g = Conv2D(inter_shape, kernel_size=1, strides=1, padding='same', 
                   kernel_initializer='he_normal', activation=None)(gating)
    phi_g = BatchNormalization()(phi_g)

    # Add components
    concat_xg = add([phi_g, theta_x])
    act_xg = Activation('relu')(concat_xg)

    # Apply convolution
    psi = Conv2D(1, kernel_size=1, strides=1, padding='same', 
                 kernel_initializer='he_normal', activation=None)(act_xg)
    psi = BatchNormalization()(psi)

    # Apply sigmoid activation
    sigmoid_xg = Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)

    # UpSample and resample to correct size
    upsample_psi = UpSampling2D(interpolation='bilinear', 
                                size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)
    
    # Use tf.shape for dynamic batch size
    batch_size = tf.shape(x)[0]
    target_shape = tf.stack([batch_size, shape_x[1], shape_x[2], shape_x[3]])
    upsample_psi = tf.broadcast_to(upsample_psi, shape=target_shape)
    
    y = multiply([upsample_psi, x])

    return y



def UNetAM(trained_weights=None, input_size=(512,512,3), num_classes=5, drop_rate=0.25, 
           lr=0.0001, filter_base=16, deep_supervision=True):

  inputs = Input(input_size)


  conv = convBlock2_improved(inputs, filter_base, 3)

  conv0 = MaxPooling2D(pool_size=(2, 2))(conv)
  conv0 = convBlock2_improved(conv0, 2 * filter_base, 3)

  pool0 = MaxPooling2D(pool_size=(2, 2))(conv0)
  conv1 = convBlock2_improved(pool0, 4 * filter_base, 3)

  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
  conv2 = convBlock2_improved(pool1, 8 * filter_base, 3)

  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
  
  conv3 = bottleneck_block(pool2, 16 * filter_base)


  up4 = Conv2DTranspose(8 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv3)
  up4 = BatchNormalization()(up4)
  up4 = Activation('relu')(up4)
  merge4 = attention_block(conv2, conv3, 8 * filter_base, drop_rate)
  conv4 = concatenate([up4, merge4])
  conv4 = convBlock2_improved(conv4, 8 * filter_base, 3)

  up5 = Conv2DTranspose(4 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv4)
  up5 = BatchNormalization()(up5)
  up5 = Activation('relu')(up5)
  merge5 = attention_block(conv1, conv4, 4 * filter_base, drop_rate)
  conv5 = concatenate([up5, merge5])
  conv5 = convBlock2_improved(conv5, 4 * filter_base, 3)

  up6 = Conv2DTranspose(2 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5)
  up6 = BatchNormalization()(up6)
  up6 = Activation('relu')(up6)
  merge6 = attention_block(conv0, conv5, 2 * filter_base, drop_rate)
  conv6 = concatenate([up6, merge6])
  conv6 = convBlock2_improved(conv6, 2 * filter_base, 3)

  up7 = Conv2DTranspose(1 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6)
  up7 = BatchNormalization()(up7)
  up7 = Activation('relu')(up7)
  merge7 = attention_block(conv, conv6, 1 * filter_base, drop_rate)
  conv7 = concatenate([up7, merge7])
  conv7 = concatenate([up7, conv])
  conv7 = convBlock2_improved(conv7, 1 * filter_base, 3)

  ## Main output
  out = Conv2D(num_classes, 1, padding='same', kernel_initializer='he_normal')(conv7)
  out = Activation('softmax', dtype='float32', name='main_output')(out)

  # Deep supervision 
  if deep_supervision:
   
    aux_out = Conv2D(num_classes, 1, padding='same', kernel_initializer='he_normal')(conv5)
    aux_out = UpSampling2D(size=(4, 4), interpolation='bilinear')(aux_out)
    aux_out = Activation('softmax', dtype='float32', name='aux_output')(aux_out)
    
    model = Model(inputs, [out, aux_out])
    
   
    model.compile(
        optimizer=adam_v2.Adam(learning_rate=lr),
        loss={'main_output': 'sparse_categorical_crossentropy',
              'aux_output': 'sparse_categorical_crossentropy'},
        loss_weights={'main_output': 0.7, 'aux_output': 0.3},
        metrics={'main_output': 'accuracy', 'aux_output': 'accuracy'}
    )
  else:
    model = Model(inputs, out)
    
    model.compile(
        optimizer=adam_v2.Adam(learning_rate=lr),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

  if trained_weights is not None:
    model.load_weights(trained_weights)

  return model

# %%
# ============================================
# Load preprocessed .npy dataset
# ============================================

import glob
import numpy as np
import os

PROCESSED_ROOT = "extra-dataset-processed-5classes"

def load_npy_pairs(split="training"):
    img_dir = os.path.join(PROCESSED_ROOT, split, "images")
    mask_dir = os.path.join(PROCESSED_ROOT, split, "masks")

    img_files = sorted(glob.glob(os.path.join(img_dir, "*.npy")))
    mask_files = sorted(glob.glob(os.path.join(mask_dir, "*.npy")))

    images = []
    masks = []

    for img_path, mask_path in zip(img_files, mask_files):
        img = np.load(img_path)    # shape: (1,512,512,3)
        mask = np.load(mask_path)  # shape: (1,512,512,1) with values 0-4

        # remove batch dimension: (1,512,512,3) → (512,512,3)
        img = img[0]
        mask = mask[0]

        images.append(img.astype("float32"))
        masks.append(mask.astype("int32"))  # Keep as integers for sparse_categorical_crossentropy

    return images, masks


# Load dataset
train_images_extra, train_masks_extra = load_npy_pairs("training")
val_images_extra, val_masks_extra = load_npy_pairs("validation")
test_images_extra, test_masks_extra = load_npy_pairs("test")

print("Loaded:")
print("  Train:", len(train_images_extra))
print("  Val:", len(val_images_extra))
print("  Test:", len(test_images_extra))

# Check mask values to ensure they are 0-4
print("\nMask value range check:")
print("  Train mask min/max:", np.min([m.min() for m in train_masks_extra]), "/", np.max([m.max() for m in train_masks_extra]))
print("  Val mask min/max:", np.min([m.min() for m in val_masks_extra]), "/", np.max([m.max() for m in val_masks_extra]))
print("  Test mask min/max:", np.min([m.min() for m in test_masks_extra]), "/", np.max([m.max() for m in test_masks_extra]))
# Out:
# Loaded:
#   Train: 7470
#   Val: 1602
#   Test: 1602
#
# Mask value range check:
#   Train mask min/max: 0 / 4
#   Val mask min/max: 0 / 4
#   Test mask min/max: 0 / 4

# %%
## Train Attention U-Net (LandCover.ai, RGB, 5 classes)
EPOCHS_EXTRA = 85
BATCH_SIZE_EXTRA = 32

def make_tf_dataset(images, masks, batch_size=8, shuffle=True):
    """Optimized data pipeline for faster training"""
    # Define generator function
    def generator():
        for img, mask in zip(images, masks):
            yield img, mask

    # Use from_generator instead of from_tensor_slices
    ds = tf.data.Dataset.from_generator(
        generator,
        output_signature=(
            tf.TensorSpec(shape=(512, 512, 3), dtype=tf.float32), # Image format
            tf.TensorSpec(shape=(512, 512, 1), dtype=tf.int32)    # Mask format (integer labels)
        )
    )

    if shuffle:
        ds = ds.shuffle(buffer_size=min(len(images), 1000))  # Increased buffer for better shuffling
    
    ds = ds.batch(batch_size)
    ds = ds.prefetch(tf.data.AUTOTUNE)  # Prefetch next batch while training current batch
    
    # Cache dataset in memory if possible (speeds up subsequent epochs)
    # Comment out if running out of RAM
    # ds = ds.cache()
    
    return ds


train_ds_extra = make_tf_dataset(train_images_extra, train_masks_extra, batch_size=BATCH_SIZE_EXTRA)
val_ds_extra = make_tf_dataset(val_images_extra, val_masks_extra, batch_size=BATCH_SIZE_EXTRA, shuffle=False)
test_ds_extra = make_tf_dataset(test_images_extra, test_masks_extra, batch_size=BATCH_SIZE_EXTRA, shuffle=False)

print(f"Training batches per epoch: {len(train_images_extra) // BATCH_SIZE_EXTRA}")
print(f"Validation batches per epoch: {len(val_images_extra) // BATCH_SIZE_EXTRA}")
# Out:
# 2025-12-09 17:25:19.786228: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-09 17:25:20.496728: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22134 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:98:00.0, compute capability: 8.9
# Training batches per epoch: 233
# Validation batches per epoch: 50

# %%
# Train on LandCover.ai extra RGB dataset (5 classes)
# Attention U-Net with Mixed Precision Training

# Enable mixed precision training for faster training on RTX 4090
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')
print("Mixed precision enabled: using float16 for computation, float32 for variables")

# Create model
am_unet_extra = UNetAM(input_size=(512,512,3), num_classes=5, filter_base=16, lr=0.0005)

# Callbacks
save_am_unet_extra = ModelCheckpoint(
    'unet-attention-extra-5classes-plus2.hdf5', 
    monitor='val_accuracy', 
    verbose=1, 
    save_best_only=True
)


# Learning rate reduction on plateau
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-5,
    verbose=1
)

# Train
history_am_unet_extra = am_unet_extra.fit(
    train_ds_extra,
    epochs=EPOCHS_EXTRA,
    validation_data=val_ds_extra,
    callbacks=[save_am_unet_extra, reduce_lr],
    verbose=1
)

# Save history
np.save('unet-attention-extra-5classes-history-plus2.npy', history_am_unet_extra.history)

print("\n" + "="*60)
print("Training completed!")
#print(f"Best validation accuracy: {max(history_am_unet_extra.history['val_accuracy']):.4f}")
#print("="*60)
# Out:
# Mixed precision enabled: using float16 for computation, float32 for variables
# Epoch 1/85
#     234/Unknown - 106s 404ms/step - loss: 1.1915 - main_output_loss: 1.2776 - aux_output_loss: 0.9905 - main_output_accuracy: 0.5587 - aux_output_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 234/234 [==============================] - 112s 432ms/step - loss: 1.1915 - main_output_loss: 1.2776 - aux_output_loss: 0.9905 - main_output_accuracy: 0.5587 - aux_output_accuracy: 0.6250 - val_loss: 1.1243 - val_main_output_loss: 1.1839 - val_aux_output_loss: 0.9854 - val_main_output_accuracy: 0.6089 - val_aux_output_accuracy: 0.6000 - lr: 5.0000e-04
# Epoch 2/85
# 234/234 [==============================] - ETA: 0s - loss: 0.9614 - main_output_loss: 0.9978 - aux_output_loss: 0.8764 - main_output_accuracy: 0.6240 - aux_output_accuracy: 0.6548WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 234/234 [==============================] - 103s 426ms/step - loss: 0.9614 - main_output_loss: 0.9978 - aux_output_loss: 0.8764 - main_output_accuracy: 0.6240 - aux_output_accuracy: 0.6548 - val_loss: 0.8881 - val_main_output_loss: 0.9057 - val_aux_output_loss: 0.8468 - val_main_output_accuracy: 0.6326 - val_aux_output_accuracy: 0.6825 - lr: 5.0000e-04
# Epoch 3/85
# 234/234 [==============================] - ETA: 0s - loss: 0.9092 - main_output_loss: 0.9266 - aux_output_loss: 0.8687 - main_output_accuracy: 0.6448 - aux_output_accuracy: 0.6548WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 234/234 [==============================] -
ARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 234/234 [==============================] - 103s 427ms/step - loss: 0.7273 - main_output_loss: 0.7285 - aux_output_loss: 0.7246 - main_output_accuracy: 0.7205 - aux_output_accuracy: 0.7205 - val_loss: 0.6613 - val_main_output_loss: 0.6617 - val_aux_output_loss: 0.6603 - val_main_output_accuracy: 0.7684 - val_aux_output_accuracy: 0.7674 - lr: 1.0000e-05
# Epoch 85/85
# 234/234 [==============================] - ETA: 0s - loss: 0.7272 - main_output_loss: 0.7285 - aux_output_loss: 0.7242 - main_output_accuracy: 0.7205 - aux_output_accuracy: 0.7207WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 234/234 [==============================] - 100s 419ms/step - loss: 0.7272 - main_output_loss: 0.7285 - aux_output_loss: 0.7242 - main_output_accuracy: 0.7205 - aux_output_accuracy: 0.7207 - val_loss: 0.6612 - val_main_output_loss: 0.6617 - val_aux_output_loss: 0.6601 - val_main_output_accuracy: 0.7685 - val_aux_output_accuracy: 0.7675 - lr: 1.0000e-05
#
# ============================================================
# Training completed!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 44>()
#      42 print("\n" + "="*60)
#      43 print("Training completed!")
# ---> 44 print(f"Best validation accuracy: {max(history_am_unet_extra.history['val_accuracy']):.4f}")
#      45 print("="*60)
#
# KeyError: 'val_accuracy'

# %%
import os

# Define the filename exactly as your evaluation code expects it
weights_filename = 'unet-attention-extra-5classes-plus2.hdf5'

# Check if the trained model object exists in memory
if 'am_unet_extra' in locals() or 'am_unet_extra' in globals():
    print("✅ Model 'am_unet_extra' found in memory. Saving now...")
    
    try:
        # Save weights (Small file size, used for inference)
        am_unet_extra.save_weights(weights_filename)
        print(f"✅ Success: Weights saved to local disk as '{weights_filename}'")
        
        # Verify file existence
        if os.path.exists(weights_filename):
            filesize = os.path.getsize(weights_filename) / (1024 * 1024)
            print(f"   File size: {filesize:.2f} MB")
        else:
            print("❌ Error: File was not created despite no error message.")
            
    except Exception as e:
        print(f"❌ Error during saving: {str(e)}")
else:
    print("❌ Critical Error: The model variable 'am_unet_extra' is not in memory.")
    print("   If you restarted the kernel, the training data is lost.")
# Out:
# ✅ Model 'am_unet_extra' found in memory. Saving now...
# ✅ Success: Weights saved to local disk as 'unet-attention-extra-5classes-plus2.hdf5'
#    File size: 10.21 MB

# %%
# Evaluation - OPTIMIZED: Single forward pass per dataset
import gc

# Load Attention U-Net
print("Loading model...")
am_unet_extra_eval = UNetAM(
    trained_weights='unet-attention-extra-5classes-plus2.hdf5',
    input_size=(512, 512, 3),
    num_classes=5,
    filter_base=16,
    lr=0.0005
)

print("\n" + "="*60)
print("VALIDATION SET EVALUATION")
print("="*60)
print(f"Validation set: {len(val_images_extra)} images\n")

# Single pass to compute all metrics
val_metrics = evaluate_all_metrics(am_unet_extra_eval, val_images_extra, val_masks_extra, num_classes=5)
val_f1 = f1_score_from_metrics(val_metrics['precision'], val_metrics['recall'])
gc.collect()

print("\n" + "="*60)
print("TEST SET EVALUATION")
print("="*60)
print(f"Test set: {len(test_images_extra)} images\n")

# Single pass to compute all metrics
test_metrics = evaluate_all_metrics(am_unet_extra_eval, test_images_extra, test_masks_extra, num_classes=5)
test_f1 = f1_score_from_metrics(test_metrics['precision'], test_metrics['recall'])
gc.collect()

print("\n" + "="*60)
print("RESULTS")
print("="*60)

# Validation metrics
metrics_extra_val = {
    'classifier': ['Attention U-Net (5 classes)'],
    'accuracy':  [np.mean(val_metrics['accuracy'])],
    'precision': [np.mean(val_metrics['precision'])],
    'recall':    [np.mean(val_metrics['recall'])],
    'f1_score':  [val_f1],
    'iou':       [np.mean(val_metrics['iou'])],
    'miou':      [np.mean(val_metrics['miou'])],
    'accuracy_std':  [np.std(val_metrics['accuracy'])],
    'precision_std': [np.std(val_metrics['precision'])],
    'recall_std':    [np.std(val_metrics['recall'])],
    'iou_std':       [np.std(val_metrics['iou'])],
    'miou_std':      [np.std(val_metrics['miou'])],
}

metrics_extra_val = pd.DataFrame(metrics_extra_val)
metrics_extra_val.to_csv('metrics_extra_val_landcover_5classes-plus2.csv', index=False)
print("\nValidation Metrics:")
print(metrics_extra_val)

# Test metrics
metrics_extra_test = {
    'classifier': ['Attention U-Net (5 classes)'],
    'accuracy':  [np.mean(test_metrics['accuracy'])],
    'precision': [np.mean(test_metrics['precision'])],
    'recall':    [np.mean(test_metrics['recall'])],
    'f1_score':  [test_f1],
    'iou':       [np.mean(test_metrics['iou'])],
    'miou':      [np.mean(test_metrics['miou'])],
    'accuracy_std':  [np.std(test_metrics['accuracy'])],
    'precision_std': [np.std(test_metrics['precision'])],
    'recall_std':    [np.std(test_metrics['recall'])],
    'iou_std':       [np.std(test_metrics['iou'])],
    'miou_std':      [np.std(test_metrics['miou'])],
}

metrics_extra_test = pd.DataFrame(metrics_extra_test)
metrics_extra_test.to_csv('metrics_extra_test_landcover_5classes-plus2.csv', index=False)
print("\nTest Metrics:")
print(metrics_extra_test)

print("\n" + "="*60)
print("Evaluation complete! Results saved to CSV files.")
print("="*60)
# Out:
# Loading model...
#
# ============================================================
# VALIDATION SET EVALUATION
# ============================================================
# Validation set: 1602 images
#
#   Processing 1602 images...
#     0/1602
#     100/1602
#     200/1602
#     300/1602
#     400/1602
#     500/1602
#     600/1602
#     700/1602
#     800/1602
#     900/1602
#     1000/1602
#     1100/1602
#     1200/1602
#     1300/1602
#     1400/1602
#     1500/1602
#     1600/1602
#     1602/1602 - Done!
#   Computing metrics from predictions...
#
# ============================================================
# TEST SET EVALUATION
# ============================================================
# Test set: 1602 images
#
#   Processing 1602 images...
#     0/1602
#     100/1602
#     200/1602
#     300/1602
#     400/1602
#     500/1602
#     600/1602
#     700/1602
#     800/1602
#     900/1602
#     1000/1602
#     1100/1602
#     1200/1602
#     1300/1602
#     1400/1602
#     1500/1602
#     1600/1602
#     1602/1602 - Done!
#   Computing metrics from predictions...
#
# ============================================================
# RESULTS
# ============================================================
#
# Validation Metrics:
#                     classifier  accuracy  precision    recall  f1_score
# 0  Attention U-Net (5 classes)  0.768507   0.803723  0.768507  0.785721  \
#
#         iou      miou  accuracy_std  precision_std  recall_std   iou_std
# 0  0.684909  0.171105      0.264214       0.226368    0.264214  0.303294  \
#
#    miou_std
# 0  0.065474
#
# Test Metrics:
#                     classifier  accuracy  precision    recall  f1_score
# 0  Attention U-Net (5 classes)  0.796348   0.818665  0.796348  0.807353  \
#
#         iou      miou  accuracy_std  precision_std  recall_std   iou_std
# 0  0.711674  0.181338      0.234675       0.209665    0.234675  0.281264  \
#
#    miou_std
# 0   0.06239
#
# ============================================================
# Evaluation complete! Results saved to CSV files.
# ============================================================

# %%
print("Loading training history...")
# Load the dictionary from the .npy file
history_dict = np.load('unet-attention-extra-5classes-history-plus2.npy', allow_pickle=True).item()

# Print all available keys to verify what Keras named them
print(f"Available keys in history: {list(history_dict.keys())}")

# Logic to automatically select the correct accuracy key
# Deep Supervision models rename metrics (e.g., 'main_output_accuracy')
if 'main_output_accuracy' in history_dict:
    print("-> Detected Deep Supervision model. Using 'main_output_accuracy'.")
    acc_key = 'main_output_accuracy'
    val_acc_key = 'val_main_output_accuracy'
    loss_key = 'loss'          # Total loss (main + aux)
    val_loss_key = 'val_loss'  # Total val loss
elif 'accuracy' in history_dict:
    print("-> Detected standard model. Using 'accuracy'.")
    acc_key = 'accuracy'
    val_acc_key = 'val_accuracy'
    loss_key = 'loss'
    val_loss_key = 'val_loss'
else:
    # Fallback for older Keras versions
    acc_key = 'acc'
    val_acc_key = 'val_acc'
    loss_key = 'loss'
    val_loss_key = 'val_loss'

# Create output directory if it doesn't exist
if not os.path.exists('figures'):
    os.makedirs('figures')

# ============================================
# 2. Plotting Accuracy
# ============================================

plt.figure(figsize=(8, 6))
# Use the detected keys dynamically
plt.plot(history_dict[acc_key], label='Training Accuracy (Main)')
plt.plot(history_dict[val_acc_key], label='Validation Accuracy (Main)')
plt.title('Attention U-Net (5 Classes) - Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Save the figure
save_path_acc = 'figures/unet-attention-5classes-accuracy-plus2.pdf'
plt.savefig(save_path_acc, dpi=300, bbox_inches='tight')
print(f"Accuracy plot saved to: {save_path_acc}")
plt.show()

# ============================================
# 3. Plotting Loss
# ============================================

plt.figure(figsize=(8, 6))
plt.plot(history_dict[loss_key], label='Total Training Loss')
plt.plot(history_dict[val_loss_key], label='Total Validation Loss')
plt.title('Attention U-Net (5 Classes) - Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()

# Save the figure
save_path_loss = 'figures/unet-attention-5classes-loss-plus2.pdf'
plt.savefig(save_path_loss, dpi=300, bbox_inches='tight')
print(f"Loss plot saved to: {save_path_loss}")
plt.show()

# ============================================
# 4. Print Summary Statistics
# ============================================

print("\n" + "="*40)
print("TRAINING SUMMARY")
print("="*40)
print(f"Best Training Accuracy:   {max(history_dict[acc_key]):.4f}")
print(f"Best Validation Accuracy: {max(history_dict[val_acc_key]):.4f}")
print(f"Final Training Loss:      {history_dict[loss_key][-1]:.4f}")
print(f"Final Validation Loss:    {history_dict[val_loss_key][-1]:.4f}")
print("="*40)
# Out:
# Loading training history...
# Available keys in history: ['loss', 'main_output_loss', 'aux_output_loss', 'main_output_accuracy', 'aux_output_accuracy', 'val_loss', 'val_main_output_loss', 'val_aux_output_loss', 'val_main_output_accuracy', 'val_aux_output_accuracy', 'lr']
# -> Detected Deep Supervision model. Using 'main_output_accuracy'.
# Accuracy plot saved to: figures/unet-attention-5classes-accuracy-plus2.pdf
# Loss plot saved to: figures/unet-attention-5classes-loss-plus2.pdf
# ========================================
# TRAINING SUMMARY
# ========================================
# Best Training Accuracy:   0.7216
# Best Validation Accuracy: 0.7705
# Final Training Loss:      0.7272
# Final Validation Loss:    0.6612
# ========================================

# %%
# ============================================
# Compute Confusion Matrix - FIXED for Deep Supervision
# ============================================

from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import gc

# Load model if not already loaded
try:
    am_unet_extra_eval
except NameError:
    print("Loading model...")
    # 请确保这里的 model 类定义已经运行过
    am_unet_extra_eval = UNetAM(
        trained_weights='unet-attention-extra-5classes-plus2.hdf5',
        input_size=(512, 512, 3),
        num_classes=5,
        filter_base=16,
        lr=0.0005
    )

# Initialize confusion matrix (5x5 for 5 classes)
cm = np.zeros((5, 5), dtype=np.int64)

print("Computing confusion matrix incrementally...")
BATCH_SIZE = 16  # 稍微调小一点 Batch 以防显存溢出

for batch_start in range(0, len(test_images_extra), BATCH_SIZE):
    batch_end = min(batch_start + BATCH_SIZE, len(test_images_extra))
    
    if batch_start % 200 == 0:
        print(f"  {batch_start}/{len(test_images_extra)}")
    
    # Prepare batch
    batch_images = []
    batch_masks = []
    
    for i in range(batch_start, batch_end):
        batch_images.append(test_images_extra[i])
        batch_masks.append(test_masks_extra[i].flatten())
    
    # Stack into batch array
    batch_images = np.array(batch_images)  # (batch_size, 512, 512, 3)
    
    # Predict batch
    raw_preds = am_unet_extra_eval.predict(batch_images, verbose=0)
    
    # === 关键修复：处理深监督多输出 ===
    if isinstance(raw_preds, list):
        batch_preds = raw_preds[0] # 取主输出
    else:
        batch_preds = raw_preds
    # ===============================
        
    batch_preds = np.argmax(batch_preds, axis=-1)  # (batch_size, 512, 512)
    
    # Update confusion matrix for each image in batch
    for pred, mask in zip(batch_preds, batch_masks):
        pred_flat = pred.flatten()
        
        # 再次确保形状一致 (虽然现在应该已经一致了)
        if len(pred_flat) != len(mask):
            print(f"Error: Shape mismatch - Pred: {len(pred_flat)}, Mask: {len(mask)}")
            continue
            
        cm += confusion_matrix(mask, pred_flat, labels=[0, 1, 2, 3, 4])
    
    # Clear memory
    del batch_images, batch_preds, batch_masks, raw_preds
    gc.collect()

print(f"  {len(test_images_extra)}/{len(test_images_extra)} - Done!")

# Plot confusion matrix
plt.figure(figsize=(10, 8))
# 使用百分比显示可能更直观，但这里保持原样显示数量
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Background', 'Building', 'Woodland', 'Water', 'Road'],
            yticklabels=['Background', 'Building', 'Woodland', 'Water', 'Road'])
plt.title('Confusion Matrix (Test Set)')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig('confusion_matrix_5classes-plus2.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nConfusion Matrix:")
print(cm)
print("\nConfusion Matrix saved to: confusion_matrix_5classes-plus2.png")
# Out:
# Computing confusion matrix incrementally...
#   0/1602
#   400/1602
#   800/1602
#   1200/1602
#   1600/1602
#   1602/1602 - Done!
# Confusion Matrix:
# [[218816930        79  19071174   2038528         1]
#  [  3826673        54    121769      8058         0]
#  [ 39057644         6 104104207   1008255         0]
#  [ 11125132         2   1754168  11508820         0]
#  [  6244985         6   1202490     65707         0]]
#
# Confusion Matrix saved to: confusion_matrix_5classes-plus2.png
